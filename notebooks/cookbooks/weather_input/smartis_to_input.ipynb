# %%
import pandas as pd
import numpy as np

# %%
smartis = pd.read_csv(
    'smartis_sample.csv',
    sep=';',
    parse_dates=['Jour'],
    dayfirst=True,
    usecols=['Jour', 'tm', 'glot', 'um']
)
smartis
# Out:
#                     Jour    tm  glot    um
# 0    2002-09-01 00:00:00  17.0     0  88.0
# 1    2002-09-01 01:00:00  18.0     0  87.0
# 2    2002-09-01 02:00:00  19.2     0  87.0
# 3    2002-09-01 03:00:00  17.3     0  89.0
# 4    2002-09-01 04:00:00  16.9     0  92.0
# ...                  ...   ...   ...   ...
# 2922 2002-12-31 19:00:00  24.8     0  88.0
# 2923 2002-12-31 20:00:00  25.0     0  86.0
# 2924 2002-12-31 21:00:00  24.7     0  82.0
# 2925 2002-12-31 22:00:00  24.1     0  83.0
# 2926 2002-12-31 23:00:00  24.2     0  94.0
#
# [2927 rows x 4 columns]

# %%
vmango_input = smartis.rename(columns={'Jour':'DATETIME', 'tm':'TM', 'glot':'GR', 'um':'RH'}, inplace=False)
vmango_input.set_index('DATETIME',inplace=True)
vmango_input
# Out:
#                        TM  GR    RH
# DATETIME
# 2002-09-01 00:00:00  17.0   0  88.0
# 2002-09-01 01:00:00  18.0   0  87.0
# 2002-09-01 02:00:00  19.2   0  87.0
# 2002-09-01 03:00:00  17.3   0  89.0
# 2002-09-01 04:00:00  16.9   0  92.0
# ...                   ...  ..   ...
# 2002-12-31 19:00:00  24.8   0  88.0
# 2002-12-31 20:00:00  25.0   0  86.0
# 2002-12-31 21:00:00  24.7   0  82.0
# 2002-12-31 22:00:00  24.1   0  83.0
# 2002-12-31 23:00:00  24.2   0  94.0
#
# [2927 rows x 3 columns]

# %%
vmango_input.to_csv('vmango_input.csv.zip')

# %%
test = pd.read_csv('vmango_input.csv.zip', index_col='DATETIME', parse_dates=['DATETIME'])
test
# Out:
#                        TM  GR    RH
# DATETIME
# 2002-09-01 00:00:00  17.0   0  88.0
# 2002-09-01 01:00:00  18.0   0  87.0
# 2002-09-01 02:00:00  19.2   0  87.0
# 2002-09-01 03:00:00  17.3   0  89.0
# 2002-09-01 04:00:00  16.9   0  92.0
# ...                   ...  ..   ...
# 2002-12-31 19:00:00  24.8   0  88.0
# 2002-12-31 20:00:00  25.0   0  86.0
# 2002-12-31 21:00:00  24.7   0  82.0
# 2002-12-31 22:00:00  24.1   0  83.0
# 2002-12-31 23:00:00  24.2   0  94.0
#
# [2927 rows x 3 columns]

# %%
test.plot(y='GR')
# Out:
# <AxesSubplot:xlabel='DATETIME'>

# %%
test.plot(y='RH')
# Out:
# <AxesSubplot:xlabel='DATETIME'>

# %%
test.plot(y='TM')
# Out:
# <AxesSubplot:xlabel='DATETIME'>
