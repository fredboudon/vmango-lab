# %%
import numpy as np
import pandas as pd
import vmlab

# %%
from vmlab.models import *

# %%
longname_model(vmango).visualize()

# %%
longname_model(arch_dev_model).visualize()

# %%
longname_model(fruit_model).visualize()

# %%
import xsimlab.dot as dot

# %%
dot.dot_graph(longname_model(vmango), 
              rankdir='TB',
              graph_attr = {'margin':'0.2', 'nodesep':'0.1', 'ranksep':'0.1'})
